# %% [markdown]
# # **PROJECT: Mini Reverse Image Search using CNN + Flask**
#
# 1. Feature Extraction Script (run once)
#
# 2. Flask Backend Code (app.py)
#
# 3. HTML Templates
#
# **By the end, you'll have a mini Reverse Image Search engine using:**
#
# ✔ CNN (VGG16)
#
# ✔ TensorFlow/Keras
#
# ✔ Cosine similarity
#
# ✔ Flask deployment
#
# ✔ A neat HTML UI

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# !pip install pillow

# %% [markdown]
# # **Step 1 - Feature Extraction Script (feature_extraction.py)**

# %%
import os
import numpy as np
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from tensorflow.keras.models import Model

# %% [markdown]
# # Load Pretrained Model

# %%
# We remove the final classification layers and only keep the feature extractor


base_model = VGG16(weights='imagenet')
model = Model(inputs=base_model.input, outputs=base_model.get_layer('fc1').output)

# %%
# Set your Google Drive image folder path
# IMAGE_DIR = "/content/drive/MyDrive/Images/"
IMAGE_DIR = 'static\Images'

# Lists to store extracted data
features = []
image_paths = []

# %% [markdown]
# # **extract_features() function**
#
#
# **The function extract_features(img_path) takes an image file path as input and returns a 4096-dimensional feature vector produced by the FC1 layer of VGG16**
#
#
# This vector is a compact numerical representation of the image and is commonly used for:
#
# Image similarity
#
# Image search engines
#
# Clustering
#
# Recommendation systems
#
#
# The steps inside the function:
#
# 1. Load image & resize to (224×224), because VGG16 requires this input size.
#
# 2. Convert the image to a NumPy array.
#
# 3. Expand the array to shape (1, 224, 224, 3) to simulate a batch (VGG expects batches).
#
# 4. Preprocess using VGG16 preprocessing (RGB → BGR, mean subtraction).
#
# 5. Pass the image into the VGG16 model and collect the FC1 layer output.
#
# 6. Normalize the resulting vector so comparisons (like cosine similarity) become stable.
#
# 7. Return the final feature vector.

# %%
# Step 2.2 — Extract features from a single image
# ---------------------------------------
def extract_features(img_path):
    img = image.load_img(img_path, target_size=(224, 224))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)

    # Preprocess for VGG16
    img_array = preprocess_input(img_array)

    # Get FC1 layer output (4096-dim)
    feature_vector = model.predict(img_array)[0]

    # Normalize the vector for stable similarity comparison
    feature_vector = feature_vector / np.linalg.norm(feature_vector)

    return feature_vector

# %% [markdown]
# **Step 2.3 — Loop through all images and extract features**

# %%
print("Extracting features...")

# Loop through every file in the image directory
for img_name in os.listdir(IMAGE_DIR):

    # Create the full path for the file
    # Example: "/content/drive/MyDrive/images/cat1.jpg"
    file_path = os.path.join(IMAGE_DIR, img_name)

    # ------------------------------------------------------------
    # Check if file is an image (only process .jpg, .jpeg, .png)
    # Helps avoid errors if the folder contains non-image files
    # ------------------------------------------------------------
    if file_path.lower().endswith((".jpg", ".jpeg", ".png")):

        # ------------------------------------------------------------
        # Extract 4096-dim VGG16 features from the image
        # The extract_features() function returns a normalized vector
        # ------------------------------------------------------------
        features.append(extract_features(file_path))

        # Save the path for later reference / image search
        image_paths.append(file_path)

        # Print progress so we know which image was processed
        print("Processed:", img_name)
# Out:
# Extracting features...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 10s 10s/step
# Processed: 00befedd19.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 423ms/step
# Processed: 0206101929.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step
# Processed: 022a8608b9.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 459ms/step
# Processed: 034292a8ff.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 448ms/step
# Processed: 0428e62301.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 479ms/step
# Processed: 043d33679c.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step
# Processed: 0465f6d586.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 467ms/step
# Processed: 04cddbbf04.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 431ms/step
# Processed: 05f5a5379d.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 463ms/step
# Processed: 06173b9a49.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 423ms/step
# Processed: 06892a0b2c.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 431ms/step
# Processed: 073bb56ea3.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 488ms/step
# Processed: 07f797c8f9.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 452ms/step
# Processed: 08510c1eeb.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 552ms/step
# Processed: 08dabf6d3d.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 414ms/step
.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step
# Processed: 80f01ae2e8.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step
# Processed: 8100ae6df1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step
# Processed: 81a2469f37.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step
# Processed: 827c616dcc.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 471ms/step
# Processed: 82c042d01d.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step
# Processed: 843b8695df.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step
# Processed: 84c8610fa6.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step
# Processed: 84e9fe2592.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step
# Processed: 850732db62.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 477ms/step
# Processed: 85b8888345.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 479ms/step
# Processed: 8603e55be2.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step
# Processed: 896568f4ac.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# Processed: 8986e1389e.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# Processed: 89ba1e76ee.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 462ms/step
# Processed: 8aa1337489.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step
# Processed: 8aa4ce3b8d.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step
# Processed: 8abe0a8428.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step
# Processed: 8ac612f3f2.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step
# Processed: 8cea89f591.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step
# Processed: 8dbf2ab0dd.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step
# Processed: 8f0de2b28b.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step
# Processed: 8f4ba63904.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step
# Processed: 8fde5ee536.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 488ms/step
# Processed: 90265e9f71.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 431ms/step
# Processed: 90aac0d31f.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 471ms/step
# Processed: 90b1132c8f.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step
# Processed: 90d94242c0.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step
# Processed: 90e538b002.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step
# Processed: 90e63a2fde.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step
# Processed: 90f1a492b5.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 444ms/step
# Processed: 912bccaa5e.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step
# Processed: 91f96f9aea.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 515ms/step
# Processed: 9296068d14.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# Processed: 932322b42d.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step
# Processed: 9349c61145.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# Processed: 93f06c9b4c.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step
# Processed: 952cdc26cd.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step
# Processed: 97ad6acb86.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# Processed: 97d58dd0e5.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step
# Processed: 97e82a7e40.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step
# Processed: 97f7609ae3.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step
# Processed: 98fdc48746.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step
# Processed: 998cc50daa.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# Processed: 9afe136e54.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step
# Processed: 9c668f7a8e.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step
# Processed: 9c6b28d6b2.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step
# Processed: 9c746729a3.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step
# Processed: 9c86add47c.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# Processed: 9c99a4f748.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step
# Processed: 9d1b62ecfd.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step
# Processed: 9d6569cd7c.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step
# Processed: 9da953d6bc.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step
# Processed: 9e83f396c1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 403ms/step
# Processed: 9ec824d4be.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 447ms/step
# Processed: 9ecbb9a0f8.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 521ms/step
# Processed: 9f0c1a7693.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 532ms/step
# Processed: a04beec2fa.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step
# Processed: a05a4fe910.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 431ms/step
# Processed: a0d8cc402a.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step
# Processed: a11170486b.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 537ms/step
# Processed: a2c69e02f4.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 499ms/step
# Processed: a31fc638ba.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step
# Processed: a33059d8dd.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step
# Processed: a3e9033a45.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 510ms/step
# Processed: a4570106d7.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 507ms/step
# Processed: a4fee8009d.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# Processed: a554d1ca8d.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step
# Processed: a589e7641c.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step
# Processed: a5d8d6406b.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step
# Processed: a64d292c5b.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 475ms/step
# Processed: a684da2e66.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 460ms/step
# Processed: a6b9bdc6b3.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 487ms/step
# Processed: a75502b717.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 467ms/step
# Processed: a80fcd1a49.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step
# Processed: a86360897d.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 458ms/step
# Processed: a87c002eb4.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 428ms/step
# Processed: a8b9081be4.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 636ms/step
# Processed: a93aac7a8b.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 557ms/step
# Processed: a999a3f7df.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step
# Processed: a9d2c5e746.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 436ms/step
# Processed: aaf4b2e726.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 436ms/step
# Processed: ab5ab33dc2.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 447ms/step
# Processed: ace8f14165.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 475ms/step
# Processed: ad83ac0b8e.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step
# Processed: ada5e192fa.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 455ms/step
# Processed: ae3ea50c93.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step
# Processed: ae7395dd50.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 403ms/step
# Processed: af1e7a6c10.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step
# Processed: af58fe4d0c.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 443ms/step
# Processed: afd4cdd8fe.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step
# Processed: afde2aeaa2.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step
# Processed: b03f182696.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step
# Processed: b05e0afbbc.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 414ms/step
# Processed: b0f373bb15.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 452ms/step
# Processed: b14b66d5ac.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step
# Processed: b241ca3982.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step
# Processed: b32ae57e79.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step
# Processed: b592266647.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step
# Processed: b59c423b44.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step
# Processed: b5efc29f94.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step
# Processed: b638f04d30.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step
# Processed: b6620393f2.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step
# Processed: b6bcd1799a.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 473ms/step
# Processed: b6ddf55180.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 438ms/step
# Processed: b84fd00535.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step
# Processed: b918453fab.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# Processed: b9818e88d5.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step
# Processed: b989ca5397.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 436ms/step
# Processed: b9b3aeabad.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 586ms/step
# Processed: b9bec06826.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 485ms/step
# Processed: b9d0e34a4f.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 474ms/step
# Processed: bbbc478e58.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 472ms/step
# Processed: bbfa1fa033.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# Processed: bc6d6d0b39.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step
# Processed: bd20f1844e.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step
# Processed: bd3daa03ba.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# Processed: bd8d59a8ea.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 455ms/step
# Processed: be2eb5f164.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# Processed: be6e6c60b4.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step
# Processed: bfa90c6ac0.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step
# Processed: c20704fb5c.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step
# Processed: c32fd96292.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 434ms/step
# Processed: c357d7dbfb.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step
# Processed: c3afbf071e.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step
# Processed: c3e90edc70.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step
# Processed: c3f0a560c2.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 455ms/step
# Processed: c5a68c2dbf.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 421ms/step
# Processed: c5c0206a36.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 529ms/step
# Processed: c5e4785e7f.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step
# Processed: c60dc9ca98.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step
# Processed: c6158f81ba.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step
# Processed: c6da62a502.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 504ms/step
# Processed: c72de4fb5e.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step
# Processed: c733e19b34.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 483ms/step
# Processed: c80174af14.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step
# Processed: c8159e2dcd.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step
# Processed: c859e91d0d.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step
# Processed: c89da83076.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# Processed: c8cd5c0582.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step
# Processed: c8eb8812b4.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step
# Processed: c9579834fd.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 444ms/step
# Processed: c9bff667d3.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step
# Processed: c9c8425411.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step
# Processed: c9f5ec7969.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 467ms/step
# Processed: ca7b087454.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step
# Processed: cb9a59ed9d.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 421ms/step
# Processed: cbe98cd720.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step
# Processed: cd32f84991.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step
# Processed: ce493f8f8b.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step
# Processed: ceb887cee3.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step
# Processed: cfae4b1fc6.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step
# Processed: d0e1076e99.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step
# Processed: d2caf17d89.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 480ms/step
# Processed: d312dafa4d.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step
# Processed: d32b2a3028.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step
# Processed: d4c283a3df.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# Processed: d50fbc47ea.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# Processed: d52466324a.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step
# Processed: d52b298e73.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# Processed: d5df1ab5ec.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 403ms/step
# Processed: d5e685f830.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step
# Processed: d6401e44b9.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 500ms/step
# Processed: d6b774417c.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 472ms/step
# Processed: d6ecb5f5fe.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step
# Processed: d780027150.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 421ms/step
# Processed: d808c27bfe.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step
# Processed: d83480b30b.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 480ms/step
# Processed: d9026e17e6.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step
# Processed: d90761a694.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 402ms/step
# Processed: d9d6f89a1e.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# Processed: da4611c65a.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step
# Processed: da57ca2ef7.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 469ms/step
# Processed: dad5f4c8ae.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step
# Processed: dbe64f56de.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step
# Processed: dd7edf9405.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step
# Processed: ddcfcff22f.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step
# Processed: df8f9e738f.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 460ms/step
# Processed: df98030606.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step
# Processed: e027e5f2b7.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 495ms/step
# Processed: e2cc8e757a.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step
# Processed: e2d573e52a.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 446ms/step
# Processed: e541dbae10.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step
# Processed: e54c17ee4d.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step
# Processed: e5811b8130.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 414ms/step
# Processed: e68641475c.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 414ms/step
# Processed: e7b50966b9.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step
# Processed: e7e9813b04.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step
# Processed: e87f9c01c0.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step
# Processed: e894ca7f24.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step
# Processed: e8c3809c55.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step
# Processed: e8cdb97b0d.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 461ms/step
# Processed: ea38a97b8f.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 545ms/step
# Processed: eb9d506eb9.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 459ms/step
# Processed: ebda3a08c3.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 432ms/step
# Processed: ec6ab64433.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 503ms/step
# Processed: ed88b96286.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step
# Processed: ee04353e8b.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 452ms/step
# Processed: ee8cf67b07.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 438ms/step
# Processed: eee6cd0c64.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 472ms/step
# Processed: ef06b77738.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 434ms/step
# Processed: f00fca6337.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 403ms/step
# Processed: f11300ddf4.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step
# Processed: f12fdd3870.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step
# Processed: f16a2899c6.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 467ms/step
# Processed: f197d84ac1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step
# Processed: f1c099b06b.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step
# Processed: f2d03571aa.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 403ms/step
# Processed: f2dc51c174.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step
# Processed: f326f71d6d.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step
# Processed: f36837e00e.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 421ms/step
# Processed: f3bd98661a.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step
# Processed: f41bf07c31.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step
# Processed: f4429b5866.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step
# Processed: f5132452ff.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 463ms/step
# Processed: f5f4707c86.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step
# Processed: f68907bc8a.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step
# Processed: f6dc6f1222.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step
# Processed: f6f687e0cd.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step
# Processed: f72a64d338.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step
# Processed: f743947a30.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step
# Processed: f76e65b482.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step
# Processed: f76f0635f1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step
# Processed: f878206183.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 403ms/step
# Processed: f88c263c1d.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 459ms/step
# Processed: f8961bffbe.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step
# Processed: f90d98e9e0.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 402ms/step
# Processed: fa0468a4ad.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step
# Processed: fb36eae184.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 403ms/step
# Processed: fb97e58510.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 467ms/step
# Processed: fbd369ea2c.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step
# Processed: fbffa9fcc1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step
# Processed: fc9462ca65.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 402ms/step
# Processed: fc9c65dbef.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step
# Processed: fd6ab69a63.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 445ms/step
# Processed: fdc5888f21.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step
# Processed: fea0bf90fd.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step
# Processed: fea1eae00b.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step
# Processed: ff5a63f32a.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 506ms/step
# Processed: ff7ce27028.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step
# Processed: ff8c0a5300.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step
# Processed: ffc2cbbe5e.jpg

# %%
# Convert to numpy arrays
features = np.array(features)
image_paths = np.array(image_paths)

# ---------------------------------------
# Step 2.4 — Save features and paths
# ---------------------------------------
np.save("features.npy", features)
np.save("image_paths.npy", image_paths)
